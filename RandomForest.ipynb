# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Data.csv')

# %%
x= dataset.iloc[:,:-1].values
y= dataset.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.25, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=0)
classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[102   5]
#  [  6  58]]
# 0.935672514619883

# %%
report = classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            2       0.94      0.95      0.95       107
#            4       0.92      0.91      0.91        64
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.93      0.93       171
# weighted avg       0.94      0.94      0.94       171

# %%
report = classification_report(y_test,y_pred,output_dict=True)
print(report)
# Out:
# {'2': {'precision': 0.9444444444444444, 'recall': 0.9532710280373832, 'f1-score': 0.9488372093023256, 'support': 107.0}, '4': {'precision': 0.9206349206349206, 'recall': 0.90625, 'f1-score': 0.9133858267716536, 'support': 64.0}, 'accuracy': 0.935672514619883, 'macro avg': {'precision': 0.9325396825396826, 'recall': 0.9297605140186915, 'f1-score': 0.9311115180369895, 'support': 171.0}, 'weighted avg': {'precision': 0.9355332776385409, 'recall': 0.935672514619883, 'f1-score': 0.9355688556066355, 'support': 171.0}}

# %%
import mlflow

# %%
mlflow.set_experiment("cellular Experiment")
mlflow.set_tracking_uri("http://127.0.0.1:5000/")
with mlflow.start_run(run_name="cellular analysis"):
    mlflow.log_metrics(
        {
            "accuracy":report["accuracy"],
            "precision_calls_2":report['2']["precision"],
            "precision_calls_4":report['4']["precision"]
        }
        )
    mlflow.sklearn.log_model(classifier,"RandomForest")
    mlflow.log_artifact(r"C:\Learning\Python\MLFlow")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[40], line 3
#       1 mlflow.set_experiment("First Experiment")
#       2 mlflow.set_tracking_uri("http://127.0.0.1:5000/")
# ----> 3 with mlflow.start_run(run_name="cellular analysis"):
#       4     mlflow.log_metrics(
#       5         {
#       6             "accuracy":report["accuracy"],
#    (...)      9         }
#      10         )
#      11     mlflow.sklearn.log_model(classifier,"RandomForest")
#
# File c:\Learning\Python\MLFlow\.venv\Lib\site-packages\mlflow\tracking\fluent.py:379, in start_run(run_id, experiment_id, run_name, nested, parent_run_id, tags, description, log_system_metrics)
#     377 experiment_id = str(experiment_id) if isinstance(experiment_id, int) else experiment_id
#     378 if len(active_run_stack) > 0 and not nested:
# --> 379     raise Exception(
#     380         (
# ...

# %%
report['0']['recall']
# Out:
# 0.9532710280373832

# %%
report["accuracy"]
# Out:
# 0.935672514619883

# %%
report["macro avg"]
# Out:
# {'precision': 0.9325396825396826,
#  'recall': 0.9297605140186915,
#  'f1-score': 0.9311115180369895,
#  'support': 171.0}
